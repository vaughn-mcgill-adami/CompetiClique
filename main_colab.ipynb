# %%
WORKING_DIRECTORY = "/content/drive/MyDrive/Colab Notebooks/CompetiClique"

import os
os.chdir(WORKING_DIRECTORY)

# %%
# !python main.py
# Out:
# loaded builder policy
# loaded builder optimizer
# loaded forbidder policy
# loaded forbidder optimizer
# 17
# best builder average return : 1.6131316423416138
# best forbidder average return : -0.21761423349380493
# latest builder average return : 1.5063323974609375
# latest forbidder average return : -2.1327462196350098
# Batch: 0/100 : playing game :  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:02:15
# Batch 0 Statistics:
# average_game_length 11.08
# max_game_length 13
# builder_loss -0.01640927605330944
# average_builder_return 1.6029658317565918
# forbidder_loss -0.021948086097836494
# average_forbidder_return -2.2146382331848145
#
#
# Batch: 1/100 : playing game :  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:02:25
